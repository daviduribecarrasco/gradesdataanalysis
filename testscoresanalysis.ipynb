# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as seabornInstance


df = pd.read_csv('data.csv')
df

df.boxplot(column='PercentGrade',by='Test')
df[(df['Test'] == 'Post')].describe()

testmean=df.drop('Term',axis=1)
testmean.groupby('Test').mean()
# Out:
#       PercentGrade
# Test
# Post     85.326176
# Pre      76.915190

# %%
#There's a noticeable improvement in the scores in the post test. The average score is higher, and the scores in the
#lower quartile are higher in the post test than they are in the pretest.

# %%
df.boxplot(column='PercentGrade',by='Instructor')

# %%
df.boxplot(column='PercentGrade',by='Term')

# %%
#There is a significant difference between the grades for the first term and the second term.The scores within the lower 
#quartile are much higher(the scores in the upper quartile are also higher, but not as markedly).

# %%
# This will put the scores from students in Instructor A's class  into a boxplot
insta = df[df['Instructor'] != 'B']
insta.boxplot(column='PercentGrade',by='Term')
insta.boxplot(column='PercentGrade',by='Test')

prescores =n
# Out:
# <ipython-input-37-10a807c47cab>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   prescores = insta[df['Test'] != 'Post']

# %%
#This will put the scores from students in Instructor B's class into a boxplot
instb = df[df['Instructor'] != 'A']
instb.boxplot(column='PercentGrade',by='Term')
